# %% [markdown]
# <a href="https://colab.research.google.com/github/charaf19/2.----------------------Part-1-Data-Preprocessing---------------------/blob/main/Professional_Preprocessing_with_Pipelines_in_Python%20NEURAL%20NINE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
